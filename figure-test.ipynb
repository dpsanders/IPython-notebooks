# %%
# %matplotlib inline
# %load_ext retina

# %%
import matplotlib as mpl
import numpy as np

from matplotlib import pyplot as plt

# %%
x = np.arange(-5, 5, 0.01)
y = x*x

plt.plot(x, y)
plt.show()
# Out:
# <img src='...' width=367 height=255/>
